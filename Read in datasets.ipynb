# %%
#READ IN LIBRARIES/PACKAGES

import os
import shutil
import pandas as pd
from datetime import datetime
from lxml import objectify
import sys

# %%
#USER INPUT: choose location and file for input *.csv

#inputloc = (r"\\Data\input_datasets\")
#outputloc = (r"\\Data\output_datasets\")
filetype = ('csv')

inputloc = input("Enter input file location:" )
inputloc = inputloc +"\\"     #+ r"\"
print("Input file location: " + inputloc)
             
#outputloc = input ("Enter output file lcoation:")
#outputloc = outputloc+"\\"    #+ r"\"
#print("Output file lcoation: " + outputloc)


#USER INPUT FILENAME

inputfile = input("Enter filename: ")
inputfile = inputfile + ".csv"
print("Input filename is: " + inputfile)


#INPUT FILE PATH
inputpath = inputloc + inputfile
print ("Full input filepath:" + inputpath)

if not os.path.exists(inputpath):
    print('{} not found'.format(inputpath))
    sys.exit()
# Out:
# Enter input file location:D:\School\Missouri PSDS\PSDS 4900\Data\input_datasets
# Input file location: D:\School\Missouri PSDS\PSDS 4900\Data\input_datasets\
# Enter filename: 2018-03-27-2021-04-05
# Input filename is: 2018-03-27-2021-04-05.csv
# Full input filepath:D:\School\Missouri PSDS\PSDS 4900\Data\input_datasets\2018-03-27-2021-04-05.csv

# %%
#READ IN AS DATAFRAME

df = pd.read_csv(inputpath)

df.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty     event_date  year  \
# 0  7767296   32       ARG7124              7124  26 March 2021  2021
# 1  7767808  887      YEM63695             63695  26 March 2021  2021
# 2  7768064  222       SLV2499              2499  26 March 2021  2021
# 3  7787008  642       ROU1529              1529  26 March 2021  2021
# 4  7788032  756        CHE198               198  26 March 2021  2021
#
#    time_precision event_type    sub_event_type  \
# 0               1   Protests  Peaceful protest
# 1               1    Battles       Armed clash
# 2               1    Battles       Armed clash
# 3               1   Protests  Peaceful protest
# 4               1   Protests  Peaceful protest
#
#                              actor1  ...                 location  latitude  \
# 0            Protesters (Argentina)  ...  San Carlos de Bariloche  -41.1335
# 1  Military Forces of Yemen (2012-)  ...               Al Kasarah   15.5381
# ...

# %%
#SUMMARY DATA FOR THE DATASET


#CHECK DATA HEADINGS

print ("HEAD", df.head(), '\n')



#DESCRIBE THE DATA

print('DESCRIBE', df.describe(), '\n')



#SHAPE OF THE DATA: number of columns and rows

print ("SHAPE", df.shape, '\n')



#INFO: infomormation of datatypes

print ("INFO", df.info(), '\n')
# Out:
# HEAD    DATA_ID  ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY     EVENT_DATE  YEAR  \
# 0  7767296   32       ARG7124              7124  26 March 2021  2021
# 1  7767808  887      YEM63695             63695  26 March 2021  2021
# 2  7768064  222       SLV2499              2499  26 March 2021  2021
# 3  7787008  642       ROU1529              1529  26 March 2021  2021
# 4  7788032  756        CHE198               198  26 March 2021  2021
#
#    TIME_PRECISION EVENT_TYPE    SUB_EVENT_TYPE  \
# 0               1   Protests  Peaceful protest
# 1               1    Battles       Armed clash
# 2               1    Battles       Armed clash
# 3               1   Protests  Peaceful protest
# 4               1   Protests  Peaceful protest
#
#                              ACTOR1  ...                 LOCATION  LATITUDE  \
# 0            Protesters (Argentina)  ...  San Carlos de Bariloche  -41.1335
# 1  Military Forces of Yemen (2012-)  ...               Al Kasarah   15.5381
# ...

# %%
#FORMAT HEADERS TO UPPERCASE
df.columns = map(str.upper, df.columns)
df.head()
# Out:
#    DATA_ID  ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY     EVENT_DATE  YEAR  \
# 0  7767296   32       ARG7124              7124  26 March 2021  2021
# 1  7767808  887      YEM63695             63695  26 March 2021  2021
# 2  7768064  222       SLV2499              2499  26 March 2021  2021
# 3  7787008  642       ROU1529              1529  26 March 2021  2021
# 4  7788032  756        CHE198               198  26 March 2021  2021
#
#    TIME_PRECISION EVENT_TYPE    SUB_EVENT_TYPE  \
# 0               1   Protests  Peaceful protest
# 1               1    Battles       Armed clash
# 2               1    Battles       Armed clash
# 3               1   Protests  Peaceful protest
# 4               1   Protests  Peaceful protest
#
#                              ACTOR1  ...                 LOCATION  LATITUDE  \
# 0            Protesters (Argentina)  ...  San Carlos de Bariloche  -41.1335
# 1  Military Forces of Yemen (2012-)  ...               Al Kasarah   15.5381
# ...

# %%
#FORMATTING

#EVENT TYPE inconsistenses with case
df['EVENT_TYPE'] = df['EVENT_TYPE'].replace({'Strategic Developments': 'Strategic developments', 
                                            'Explosion/Remote Violence':'Explosions/Remote violence', 
                                            'Explosions/remote violence':'Explosions/Remote violence'})

df['SUB_EVENT_TYPE'] = df['SUB_EVENT_TYPE'].replace({'Peaceful Protest':'Peaceful protest', 
                                                    'Armed Clash':'Armed clash', 'Mob Violence':
                                                     'Mob violence'})


#STANDARDIZE EVENT FIELDS
#strip white spaces
df["EVENT_TYPE"]=df["EVENT_TYPE"].str.strip()
df["SUB_EVENT_TYPE"]=df["SUB_EVENT_TYPE"].str.strip()
df["EVENT_ID_CNTY"]=df["EVENT_ID_CNTY"].str.strip()

# %%
#USER OUTPUT: Choose location and filname for *.csv output file

outputloc = input ("Enter output file lcoation:")
outputloc = outputloc+"\\"    #+ r"\"
print("Output file location: " + outputloc)

outputfile = input("Enter desired output filename: ")
outputfile = outputfile + ".csv"
print("Output filename is: " + outputfile)


#OUTPUT FILE PATH
outputpath = outputloc + outputfile
print ("Full output filepath:" + outputpath)
# Out:
# Enter output file lcoation:D:\School\Missouri PSDS\PSDS 4900\Data\output_datasets
# Output file location: D:\School\Missouri PSDS\PSDS 4900\Data\output_datasets\
# Enter desired output filename: 2018-03-27-2021-04-05_FORMATTED
# Output filename is: 2018-03-27-2021-04-05_FORMATTED.csv
# Full output filepath:D:\School\Missouri PSDS\PSDS 4900\Data\output_datasets\2018-03-27-2021-04-05_FORMATTED.csv

# %%
#CREATE OUTPUT FILE: will be formatted and can be used for back-up
df.to_csv(outputpath, index = False)

print ("Output *.csv Complete")
# Out:
# Output *.csv Complete
